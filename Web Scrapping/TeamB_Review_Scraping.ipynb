# %% [markdown]
# # Review Extraction By Selenium

# %%
#import packages
from selenium import webdriver as wb 
import time
import csv
import pandas as pd
from selenium.common.exceptions import NoSuchElementException

# %%
#creating empty lists
Name=[]
Rating=[]
Oneliner=[]
Review=[]

# %% [markdown]
# ## Data Extraction Code

# %%
#path for driver
webD=wb.Chrome(executable_path="C:\Program Files (x86)\chromedriver_win32\chromedriver.exe")
webD.maximize_window()

### Loop for multiple pages 
for i in range(1,501):
    #changing URl
    webD.get('https://www.amazon.in/New-Apple-iPhone-11-128GB/product-reviews/B08L8CXFZ1/ref=cm_cr_getr_d_paging_btm_prev_1?ie=UTF8&reviewerType=all_reviews&pageNumber='+str(i)+'')
    time.sleep(0.1)
    for j in range(1,11):
        try:
            name=webD.find_element_by_xpath('/html/body/div[1]/div[3]/div/div[1]/div/div[1]/div[5]/div[3]/div/div['+str(j)+']/div/div/div[1]/a/div[2]/span')
            Name.append(name.text)
        except NoSuchElementException:
            Name.append(None)
            
        try:
            rating=webD.find_element_by_xpath('/html/body/div[1]/div[3]/div/div[1]/div/div[1]/div[5]/div[3]/div/div['+str(j)+']/div/div/div[2]/a[1]/i/span').get_attribute('innerHTML')
                                           
            Rating.append(rating)
        except NoSuchElementException:
            Rating.append(None)
            
        try:
            oneliner=webD.find_element_by_xpath('/html/body/div[1]/div[3]/div/div[1]/div/div[1]/div[5]/div[3]/div/div['+str(j)+']/div/div/div[2]/a[2]/span').text
            Oneliner.append(oneliner)
        except NoSuchElementException:
            Oneliner.append(None)
            
        try:
            review=webD.find_element_by_xpath('/html/body/div[1]/div[3]/div/div[1]/div/div[1]/div[5]/div[3]/div/div['+str(j)+']/div/div/div[4]/span/span')
            Review.append(review.text)
        except NoSuchElementException:
            Review.append(None)

# %% [markdown]
# ## Checking Data

# %%
len(Review)
# Out:
# 5000

# %%
Oneliner
# Out:
# ['Do not buy iphone or expensive product from Amazom',
#  'Don’t buy it from this seller',
#  'Solid premium phone from Apple',
#  'First Time iPhone User Review :-)',
#  'Worst Experience Ever.!',
#  'iPhone 11',
#  'Defective Iphone 11',
#  'Too much heat on normal use',
#  'not a good product',
#  'Provided with a defective product',
#  'Dont rush to buy and waste your money',
#  'Black spot found on the new phone.',
#  'Best iPhone ever | Super Night Mode | Super Camera | Yellow',
#  'Heating issue',
#  'Defective model',
#  'Samsung s10 is better than iphone',
#  'Not good product',
#  'iPhone XR with better Camera and Internals',
#  'Not recommended',
#  "Don't buy from Amazon",
#  'Bad quality product',
#  'iPhone 11 already opened/used',
#  'Minor damage to the product',
#  'IT’S A TRAP',
#  'Terrific purchase: iPhone 11 White 128GB',
#  'Defective handset iPhone 11',
#  'The feel of it!',
#  'Best ever',
#  'Lack of customer loyalty and too many faulty devices',
# ...

# %%
rating
# Out:
# '5.0 out of 5 stars'

# %%
Rating
# Out:
# ['1.0 out of 5 stars',
#  '1.0 out of 5 stars',
#  '5.0 out of 5 stars',
#  '5.0 out of 5 stars',
#  '1.0 out of 5 stars',
#  '1.0 out of 5 stars',
#  '1.0 out of 5 stars',
#  '1.0 out of 5 stars',
#  '1.0 out of 5 stars',
#  '1.0 out of 5 stars',
#  '1.0 out of 5 stars',
#  '1.0 out of 5 stars',
#  '5.0 out of 5 stars',
#  '1.0 out of 5 stars',
#  '1.0 out of 5 stars',
#  '1.0 out of 5 stars',
#  '1.0 out of 5 stars',
#  '5.0 out of 5 stars',
#  '1.0 out of 5 stars',
#  '1.0 out of 5 stars',
#  '1.0 out of 5 stars',
#  '1.0 out of 5 stars',
#  '1.0 out of 5 stars',
#  '1.0 out of 5 stars',
#  '5.0 out of 5 stars',
#  '1.0 out of 5 stars',
#  '5.0 out of 5 stars',
#  '5.0 out of 5 stars',
#  '1.0 out of 5 stars',
#  '1.0 out of 5 stars',
#  '5.0 out of 5 stars',
#  '1.0 out of 5 stars',
#  '1.0 out of 5 stars',
#  '1.0 out of 5 stars',
#  '5.0 out of 5 stars',
#  '1.0 out of 5 stars',
#  '3.0 out of 5 stars',
#  '2.0 out of 5 stars',
#  '5.0 out of 5 stars',
#  '1.0 out of 5 stars',
# ...

# %%
Name
# Out:
# ['Neha',
#  'Krusshna',
#  'shanu Kumar',
#  'Sunny Kumar',
#  'Amazon Customer',
#  'Satyapal singh',
#  'Gurmeet singh',
#  'Vinay Kumar Gupta',
#  'ritesh',
#  'NAZAR',
#  'Madhusudan',
#  'Vinayak',
#  'Ghar Sayan',
#  'Bhawna juyal',
#  'gaurav garg',
#  'Shipra Goyal',
#  'D.mohanbabu',
#  'Keshav Alur',
#  'kIRTAN',
#  'Deekshant sharma',
#  'Aditya KHADYE',
#  'Jaspreet',
#  'Amazon Customer',
#  'Saranya Gannavarapu',
#  'Om Prakash',
#  'anita m.',
#  'Anup K.',
#  'Harjeet',
#  'little F.',
#  'Amazon Customer',
#  'Arun',
#  'raghu',
#  'NK',
#  'Prasanna',
#  'Amit',
#  'Amazon Customer',
#  'Santosh',
#  'Sushant',
#  'Aditya',
#  'ritesh',
#  'Lalit 009',
#  'Ajay Augustin',
#  'Alok Yadav',
#  'Geet chopra',
#  'Rahul maru',
#  'Ramesh T',
#  'lakshay manik',
#  'Sunil Rigesow',
#  'Anugra',
#  'Navi/Navtej Singh Duggal',
#  'sandeep',
#  'Engagement Media',
#  'Satish',
#  'Abhishek',
#  'Arnab Biswas',
#  'veronica',
#  'Curious',
#  'Murshitha Raziq',
# ...

# %% [markdown]
# # Saving DataFrame

# %%
df={

    'Name':Name,
    'Rating':Rating,
    'Oneliner Review':Oneliner,
    'Review':Review,
    
    
}

dataset=pd.DataFrame(data=df)

# %%
dataset.head()
# Out:
#               Name              Rating  \
# 0             Neha  1.0 out of 5 stars
# 1         Krusshna  1.0 out of 5 stars
# 2      shanu Kumar  5.0 out of 5 stars
# 3      Sunny Kumar  5.0 out of 5 stars
# 4  Amazon Customer  1.0 out of 5 stars
#
#                                      Oneliner Review  \
# 0  Do not buy iphone or expensive product from Am...
# 1                      Don’t buy it from this seller
# 2                     Solid premium phone from Apple
# 3                  First Time iPhone User Review :-)
# 4                            Worst Experience Ever.!
#
#                                               Review
# 0  Please do not buy expensive product like iphon...
# 1  Bought the mobile from appario retail ltd. Mob...
# 2  Awesome Phone. Nice upgrade from iPhone 6s to ...
# 3  The iPhone design is good and the camera quali...
# 4  My Phone is Producing Too Much Heat Even Didn’...

# %%
dataset.to_excel("Final_Data_NLP.xlsx")
